# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhankar77/EDA/blob/main/M1W3_Guided_Project_EDA_on_IMDB_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
# ## As a data scientist, you have to first explore the data and check its sanity.
#
# ## Further, you have to answer the following questions:
# 1. ### <b> Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.</b>
# 2. ### <b>This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)? </b>
# 3. ### <b> Find out the unique genres of movies in this dataset.</b>
# 4. ### <b> Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI? </b>
# 5. ### <b> Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor. </b>
# 6. ### <b>Top 3 directors prefer which actors the most? </b>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Exploration

# %%
#Import package
import pandas as pd
import numpy as np

# %%
#call imdb data
path='/content/drive/MyDrive/Colab Notebooks/imdb_data.csv'
imdb_df = pd.read_csv(path)

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
list(imdb_df.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
x = 'string'
a = list(x)
print(a)
# Out:
# ['s', 't', 'r', 'i', 'n', 'g']

# %%
type(imdb_df.loc[0,'crew'])
# Out:
# str

# %%
print(imdb_df['crew'][0])
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8', 'department': 'Directing', 'gender': 0, 'id': 1449071, 'job': 'First Assistant Director', 'name': 'Kelly Cantley', 'profile_path': None}, {'credit_id': '52fe4ee7c3a36847f82afad7', 'department': 'Directing', 'gender': 2, 'id': 3227, 'job': 'Director', 'name': 'Steve Pink', 'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'}, {'credit_id': '5524ed25c3a3687ded000d88', 'department': 'Writing', 'gender': 2, 'id': 347335, 'job': 'Writer', 'name': 'Josh Heald', 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'credit_id': '5524ed2d925141720c001128', 'department': 'Writing', 'gender': 2, 'id': 347335, 'job': 'Characters', 'name': 'Josh Heald', 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'credit_id': '5524ed3d92514166c1004a5d', 'department': 'Production', 'gender': 2, 'id': 57822, 'job': 'Producer', 'name': 'Andrew Panay', 'profile_path': None}, {'credit_id': '5524ed4bc3a3687df3000dd2', 'department': 'Production', 'gender': 0, 'id': 14
# ...

# %%
print(imdb_df.loc[0,'crew'])
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8', 'department': 'Directing', 'gender': 0, 'id': 1449071, 'job': 'First Assistant Director', 'name': 'Kelly Cantley', 'profile_path': None}, {'credit_id': '52fe4ee7c3a36847f82afad7', 'department': 'Directing', 'gender': 2, 'id': 3227, 'job': 'Director', 'name': 'Steve Pink', 'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'}, {'credit_id': '5524ed25c3a3687ded000d88', 'department': 'Writing', 'gender': 2, 'id': 347335, 'job': 'Writer', 'name': 'Josh Heald', 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'credit_id': '5524ed2d925141720c001128', 'department': 'Writing', 'gender': 2, 'id': 347335, 'job': 'Characters', 'name': 'Josh Heald', 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'credit_id': '5524ed3d92514166c1004a5d', 'department': 'Production', 'gender': 2, 'id': 57822, 'job': 'Producer', 'name': 'Andrew Panay', 'profile_path': None}, {'credit_id': '5524ed4bc3a3687df3000dd2', 'department': 'Production', 'gender': 0, 'id': 14
# ...

# %%
type(imdb_df.loc[0,'crew'])
# Out:
# str

# %%
imdb_df.loc[~imdb_df['genres'].isna()]
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb_df['crew'][0]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
columns_to_keep = ['budget', 'genres', 'original_language', 'Original_title', 'cast' , 'crew', 'revenue']

# %%
# not null values of genres
imdb_df.loc[~imdb_df['genres'].isna(),'genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
type(imdb_df.loc[0, 'cast'])
# Out:
# str

# %%
imdb_df_new = imdb_df.copy()

# %%
imdb_df_new.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
type(eval(imdb_df.loc[0,'crew'])
# Out:
# list

# %%
crew_list = eval(imdb_df.loc[0,'crew'])

# %%
crew_list
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
crew_list
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
len(crew_list)
# Out:
# 72

# %%
eval(imdb_df.loc[0,'genres'])
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
len(eval(imdb_df.loc[0,'genres']))
# Out:
# 1

# %%
columns_to_keep = ['budget', 'genres', 'imdb_id', 'original_language', 'original_title', 'cast' , 'crew', 'revenue']

# %%
imdb_df = imdb_df[columns_to_keep]

# %%
imdb_df
# Out:
#         budget                                             genres    imdb_id  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
# ...        ...                                                ...        ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  tt0109403
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...  tt2364975
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...  tt0116908
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  tt0343135
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...  tt1600195
#
# ...

# %%
#we need to apply convert string to list on: genres, cast and crew
def convert_string_to_list(str):
  return eval(str)

# %%
#apply defined function to genres
imdb_df.loc[~imdb_df['genres'].isna(), 'genres'] = imdb_df.loc[~imdb_df['genres'].isna(), 'genres'].apply(convert_string_to_list)
imdb_df.loc[~imdb_df['crew'].isna(), 'crew'] = imdb_df.loc[~imdb_df['crew'].isna(), 'crew'].apply(convert_string_to_list)
imdb_df.loc[~imdb_df['cast'].isna(), 'cast'] = imdb_df.loc[~imdb_df['cast'].isna(), 'cast'].apply(convert_string_to_list)

# %%
kk = imdb_df.loc[~imdb_df['genres'].isna(), 'genres'].apply(convert_string_to_list)
kk
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c7b9883745dc> in <module>
# ----> 1 kk = imdb_df.loc[~imdb_df['genres'].isna(), 'genres'].apply(convert_string_to_list)
#       2 kk
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
imdb_df.loc[0,'genres']
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
#apply same function to cast
imdb_df.loc[~imdb_df['cast'].isna(), 'cast'] = imdb_df.loc[~imdb_df['cast'].isna(), 'cast'].apply(convert_string_to_list)

# %%
imdb_df.loc[0, 'cast']
# Out:
# [{'cast_id': 4,
#   'character': 'Lou',
#   'credit_id': '52fe4ee7c3a36847f82afae7',
#   'gender': 2,
#   'id': 52997,
#   'name': 'Rob Corddry',
#   'order': 0,
#   'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'},
#  {'cast_id': 5,
#   'character': 'Nick',
#   'credit_id': '52fe4ee7c3a36847f82afaeb',
#   'gender': 2,
#   'id': 64342,
#   'name': 'Craig Robinson',
#   'order': 1,
#   'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'},
#  {'cast_id': 6,
#   'character': 'Jacob',
#   'credit_id': '52fe4ee7c3a36847f82afaef',
#   'gender': 2,
#   'id': 54729,
#   'name': 'Clark Duke',
#   'order': 2,
#   'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'},
#  {'cast_id': 7,
#   'character': 'Adam Jr.',
#   'credit_id': '52fe4ee7c3a36847f82afaf3',
#   'gender': 2,
#   'id': 36801,
#   'name': 'Adam Scott',
#   'order': 3,
#   'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'},
#  {'cast_id': 8,
#   'character': 'Hot Tub Repairman',
#   'credit_id': '52fe4ee7c3a36847f82afaf7',
# ...

# %%
#apply same function to crew
imdb_df.loc[~imdb_df['crew'].isna(), 'crew'] = imdb_df.loc[~imdb_df['crew'].isna(), 'crew'].apply(convert_string_to_list)
imdb_df.loc[0, 'crew']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e3d430081306> in <module>
#       1 #apply same function to crew
# ----> 2 imdb_df.loc[~imdb_df['crew'].isna(), 'crew'] = imdb_df.loc[~imdb_df['crew'].isna(), 'crew'].apply(convert_string_to_list)
#       3 imdb_df.loc[0, 'crew']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
imdb_df_new = imdb_df.copy()

# %%
imdb_df_new.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_df_new.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
imdb_df_new.loc[0,'budget']
# Out:
# 14000000

# %%
imdb_df_new.loc[imdb_df_new['budget']<1000].shape
# Out:
# (830, 23)

# %%
imdb_df_new.loc[imdb_df_new['revenue']<1000].shape
# Out:
# (57, 23)

# %%
imdb_df_new.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
#replace all the value of budget and revenue which has value less tha 1000 to the median of all values of budget and revenue which has >= 1000 value
imdb_df_new.loc[imdb_df_new['budget'] < 1000, 'budget'] = imdb_df_new.loc[imdb_df_new['budget'] >= 1000, 'budget'].median()
imdb_df_new.loc[imdb_df_new['revenue'] < 1000, 'revenue'] = imdb_df_new.loc[imdb_df_new['revenue'] >= 1000, 'revenue'].median()

# %%
imdb_df_new.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.708250e+07     8.463274   107.856571  6.705811e+07
# std     866.169729  3.492773e+07    12.104000    22.086434  1.373917e+08
# min       1.000000  2.500000e+03     0.000001     0.000000  1.404000e+03
# 25%     750.750000  1.000000e+07     4.018053    94.000000  2.947600e+06
# 50%    1500.500000  1.645000e+07     7.374861   104.000000  1.748753e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
##create profit column
imdb_df_new['profit']= imdb_df_new['revenue'] - imdb_df_new['budget']

# %%
imdb_df_new.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit'],
#       dtype='object')

# %%
imdb_df_new.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN  16450000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
#calculate maximum profit
max_profit = imdb_df_new['profit'].max()
max_profit
# Out:
# 1316249360

# %%
max_profit_movie_df = imdb_df_new[imdb_df_new['profit']== max_profit]

# %%
max_profit_movie_df
# Out:
#         id                              belongs_to_collection     budget  \
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
#
#                               genres                  homepage    imdb_id  \
# 1761  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/  tt2820852
#
#      original_language original_title  \
# 1761                en      Furious 7
#
#                                                overview  popularity  ...  \
# 1761  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
#
#      runtime                          spoken_languages    status  \
# 1761   137.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                   tagline      title  \
# 1761  Vengeance Hits Home  Furious 7
#
#                                                Keywords  \
# 1761  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
#
#                                                    cast  \
# ...

# %%
max_profit_movie_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit'],
#       dtype='object')

# %%
crew_list = max_profit_movie_df.loc[1761,'crew']

# %%
crew_list
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e693',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 8162,
#   'job': 'Characters',
#   'name': 'Gary Scott Thompson',
#   'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e699',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 2127,
# ...

# %%
# extract producer name and director name
producer_list = []
director_list = []
for elem in crew_list:
  if elem['job'] == 'Producer':
    producer_list.append(elem['name'])
    print(f"The producer for movie is {elem['name']}")
  if elem['job'] == 'Director':
    director_list.append(elem['name'])
    print(f"The directro for movie is {elem['name']}")
# Out:
# The producer for movie is Vin Diesel
# The producer for movie is Neal H. Moritz
# The directro for movie is James Wan
# The producer for movie is Michael Fottrell
# The producer for movie is Brandon Birtell

# %%
producer_list
# Out:
# ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell']

# %%
director_list
# Out:
# ['James Wan']

# %%
cast_list = max_profit_movie_df.iloc[0]['cast']

# %%
cast_list
# Out:
# [{'cast_id': 17,
#   'character': 'Dominic Toretto',
#   'credit_id': '5431dfd10e0a265915002c34',
#   'gender': 2,
#   'id': 12835,
#   'name': 'Vin Diesel',
#   'order': 0,
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'cast_id': 19,
#   'character': "Brian O'Conner",
#   'credit_id': '5431dfe4c3a3681143002b98',
#   'gender': 2,
#   'id': 8167,
#   'name': 'Paul Walker',
#   'order': 1,
#   'profile_path': '/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg'},
#  {'cast_id': 18,
#   'character': 'Hobbs',
#   'credit_id': '5431dfdbc3a36831a6004376',
#   'gender': 2,
#   'id': 18918,
#   'name': 'Dwayne Johnson',
#   'order': 2,
#   'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'},
#  {'cast_id': 20,
#   'character': 'Letty',
#   'credit_id': '5431dfeec3a36811ef002c75',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 3,
#   'profile_path': '/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg'},
#  {'cast_id': 28,
#   'character': 'Roman',
# ...

# %%
actor_name_list = []
for elem in cast_list:
  actor_name_list.append(elem['name'])

# %%
actor_name_list
# Out:
# ['Vin Diesel',
#  'Paul Walker',
#  'Dwayne Johnson',
#  'Michelle Rodriguez',
#  'Tyrese Gibson',
#  'Ludacris',
#  'Jordana Brewster',
#  'Djimon Hounsou',
#  'Tony Jaa',
#  'Ronda Rousey',
#  'Nathalie Emmanuel',
#  'Kurt Russell',
#  'Jason Statham',
#  'Sung Kang',
#  'Gal Gadot',
#  'Lucas Black',
#  'Elsa Pataky',
#  'Noel Gugliemi',
#  'John Brotherton',
#  'Luke Evans',
#  'Ali Fazal',
#  'Miller Kimsey',
#  'Charlie Kimsey',
#  'Eden Estrella',
#  'Gentry White',
#  'Iggy Azalea',
#  'Jon Lee Brody',
#  'Levy Tran',
#  'Anna Colwell',
#  'Viktor Hernandez',
#  'Steve Coulter',
#  'Robert Pralgo',
#  'Antwan Mills',
#  'J.J. Phillips',
#  'Jorge Ferragut',
#  'Sara Sohn',
#  'Benjamin Blankenship',
#  'D.J. Hapa',
#  'T-Pain',
#  'Brian Mahoney',
#  'Brittney Alger',
#  'Romeo Santos',
#  'Jocelin Donahue',
#  'Stephanie Langston',
#  'Jorge-Luis Pallo',
#  'Tego Calderón',
#  'Nathalie Kelley',
#  'Shad Moss',
#  'Don Omar',
#  'Klement Tinaj',
#  'Caleb Walker',
# ...

# %% [markdown]
# ## Question 2

# %%
#que 2
imdb_df_new['roi']= 100* imdb_df_new['profit']/imdb_df_new['budget']

# %%
imdb_df_new
# Out:
#         budget  ...          roi
# 0     14000000  ...   -12.038207
# 1     40000000  ...   137.873588
# 2      3300000  ...   296.727273
# 3      1200000  ...  1233.333333
# 4     16450000  ...   -76.146079
# ...        ...  ...          ...
# 2995  16450000  ...   -90.293696
# 2996  16450000  ...   -98.902188
# 2997  65000000  ...    37.625786
# 2998  42000000  ...   309.436633
# 2999  35000000  ...   134.534729
#
# [3000 rows x 10 columns]

# %%
#we will groupby on the original language and calculate the mean of roi
roi_language_df = imdb_df_new.groupby('original_language')['roi'].max().reset_index()

# %%
roi_language_df
# Out:
#    original_language           roi
# 0                 ar -9.180701e+01
# 1                 bn -9.673943e+01
# 2                 cn  4.389584e+02
# 3                 cs -9.989427e+01
# 4                 da  3.006667e+02
# 5                 de  4.165251e+03
# 6                 el  5.198013e+03
# 7                 en  1.288939e+06
# 8                 es  1.929867e+03
# 9                 fa  4.000000e+02
# 10                fi  9.791030e+00
# 11                fr  3.180622e+03
# 12                he  4.562924e+02
# 13                hi  2.880769e+03
# 14                hu -8.716555e+01
# 15                id -4.161758e+01
# 16                it  1.047000e+03
# 17                ja  6.242024e+02
# 18                ko  2.215690e+05
# 19                ml  7.333333e+02
# 20                mr  1.933333e+02
# 21                nb  1.884794e+01
# 22                nl  1.678571e+02
# 23                no  1.480828e+02
# 24                pl  6.084933e+02
# 25                pt  9.298993e+01
# ...

# %%
roi_language_df['roi'].max()
# Out:
# 1288938.6666666667

# %%
max_roi_lan = roi_language_df[roi_language_df['roi'] == roi_language_df['roi'].max()]['original_language']

# %%
max_roi_lan
# Out:
# 7    en
# Name: original_language, dtype: object

# %%
print(f"The language with the highest roi value :" , max_roi_lan.values)
# Out:
# The language with the highest roi value : ['en']

# %% [markdown]
# ## Question 3

# %%
#que 3
imdb_df_no_na_genres = imdb_df_new[~imdb_df_new['genres'].isna()]

# %%
for elem in imdb_df_no_na_genres.iloc[0:5].iterrows():
  print(elem)
# Out:
# (0, budget                                                        14000000
# genres                                  [{'id': 35, 'name': 'Comedy'}]
# imdb_id                                                      tt2637294
# original_language                                                   en
# original_title                                  Hot Tub Time Machine 2
# cast                 [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                 [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# revenue                                                       12314651
# profit                                                        -1685349
# roi                                                           -12.0382
# Name: 0, dtype: object)
# (1, budget                                                        40000000
# genres               [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# imdb_id                                                      tt0368933
# ...

# %%
for index, row in imdb_df_no_na_genres.iloc[0:5].iterrows():
  print(index)
  print(row)
# Out:
# 0
# budget                                                        14000000
# genres                                  [{'id': 35, 'name': 'Comedy'}]
# imdb_id                                                      tt2637294
# original_language                                                   en
# original_title                                  Hot Tub Time Machine 2
# cast                 [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                 [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# revenue                                                       12314651
# profit                                                        -1685349
# roi                                                           -12.0382
# Name: 0, dtype: object
# 1
# budget                                                        40000000
# genres               [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# imdb_id                                                      tt0368933
# ...
